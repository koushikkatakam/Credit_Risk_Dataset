# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
df = pd.read_csv('credit_risk_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %% [markdown]
# ### Typecasting

# %%
df['person_home_ownership'] = df['person_home_ownership'].astype(str)
df['loan_intent'] = df['loan_intent'].astype(str)
df['loan_grade'] = df['loan_grade'].astype(str)
df['cb_person_default_on_file'] = df['cb_person_default_on_file'].astype(str)

# %% [markdown]
# ### Null values

# %%
df.isna().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df.fillna(method = 'ffill', inplace = True)
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\3916497771.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill', inplace = True)

# %%
df.isna().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               32581 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
fig, axs = plt.subplots(3,3, figsize=(15,10), constrained_layout=True)
fig.suptitle("Quality of Features")

sns.boxplot(data=df, x='person_age', ax=axs[0][0])

sns.boxplot(data=df, x='person_income', ax=axs[0][1])

sns.boxplot(data=df,x='person_emp_length',  ax=axs[0][2])

sns.boxplot(data=df,x='loan_amnt',  ax=axs[1][0])

sns.boxplot(data=df,x='loan_int_rate',ax=axs[1][1])

sns.boxplot(data=df,x='loan_percent_income',  ax=axs[1][2])

sns.boxplot(data=df,x='cb_person_cred_hist_length',  ax=axs[2][0])

fig.delaxes(axs[1][5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 18
#      14 sns.boxplot(data=df,x='loan_percent_income',  ax=axs[1][2])
#      16 sns.boxplot(data=df,x='cb_person_cred_hist_length',  ax=axs[2][0])
# ---> 18 fig.delaxes(axs[1][5])
#      19 plt.show()
#
# IndexError: index 5 is out of bounds for axis 0 with size 3

# %% [markdown]
# ### Duplicate Removal

# %%
df.duplicated().sum()
# Out:
# 139

# %%
df.drop_duplicates(keep='first',inplace=True,ignore_index=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32442 entries, 0 to 32441
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32442 non-null  int64
#  1   person_income               32442 non-null  int64
#  2   person_home_ownership       32442 non-null  object
#  3   person_emp_length           32442 non-null  float64
#  4   loan_intent                 32442 non-null  object
#  5   loan_grade                  32442 non-null  object
#  6   loan_amnt                   32442 non-null  int64
#  7   loan_int_rate               32442 non-null  float64
#  8   loan_status                 32442 non-null  int64
#  9   loan_percent_income         32442 non-null  float64
#  10  cb_person_default_on_file   32442 non-null  object
#  11  cb_person_cred_hist_length  32442 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df['loan_status'] = df['loan_status'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32442 entries, 0 to 32441
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32442 non-null  int64
#  1   person_income               32442 non-null  int64
#  2   person_home_ownership       32442 non-null  object
#  3   person_emp_length           32442 non-null  float64
#  4   loan_intent                 32442 non-null  object
#  5   loan_grade                  32442 non-null  object
#  6   loan_amnt                   32442 non-null  int64
#  7   loan_int_rate               32442 non-null  float64
#  8   loan_status                 32442 non-null  object
#  9   loan_percent_income         32442 non-null  float64
#  10  cb_person_default_on_file   32442 non-null  object
#  11  cb_person_cred_hist_length  32442 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32442.000000   3.244200e+04       32442.000000  32442.000000
# mean      27.745053   6.607961e+04           4.779915   9591.133407
# std        6.353257   6.199979e+04           4.140934   6322.101967
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12218.750000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length
# count   32442.000000         32442.000000                32442.000000
# mean       11.018334             0.170226                    5.810338
# std         3.240439             0.106798                    4.058350
# min         5.420000             0.000000                    2.000000
# ...

# %% [markdown]
# ### Univariate

# %% [markdown]
# ## Numerical columns

# %% [markdown]
# #### Person Age

# %% [markdown]
# - person age distribution is right skewed

# %%
Q1 = df['person_age'].quantile(0.10)
Q3 = df['person_age'].quantile(0.90)

# Filter the data to include only values within the IQR
df_filtered = df[(df['person_age'] >= Q1) & (df['person_age'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['person_age'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='person_age', ylabel='Density'>

# %% [markdown]
# #### person_income

# %% [markdown]
# - Person_income widely ditributed and sightly right skewed

# %%
Q1 = df['person_income'].quantile(0.10)
Q3 = df['person_income'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['person_income'] >= Q1) & (df['person_income'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['person_income'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='person_income', ylabel='Density'>

# %% [markdown]
# #### person_emp_length

# %%
Q1 = df['person_emp_length'].quantile(0.10)
Q3 = df['person_emp_length'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['person_emp_length'] >= Q1) & (df['person_emp_length'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['person_emp_length'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='person_emp_length', ylabel='Density'>

# %% [markdown]
# #### loan_amnt

# %%
Q1 = df['loan_amnt'].quantile(0.10)
Q3 = df['loan_amnt'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['loan_amnt'] >= Q1) & (df['loan_amnt'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['loan_amnt'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='loan_amnt', ylabel='Density'>

# %% [markdown]
# #### loan_int_rate

# %%
Q1 = df['loan_int_rate'].quantile(0.10)
Q3 = df['loan_int_rate'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['loan_int_rate'] >= Q1) & (df['loan_int_rate'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['loan_int_rate'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='loan_int_rate', ylabel='Density'>

# %% [markdown]
# #### loan_percent_income

# %%
Q1 = df['loan_percent_income'].quantile(0.10)
Q3 = df['loan_percent_income'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['loan_percent_income'] >= Q1) & (df['loan_percent_income'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['loan_percent_income'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='loan_percent_income', ylabel='Density'>

# %% [markdown]
# #### cb_person_cred_hist_length

# %%
Q1 = df['cb_person_cred_hist_length'].quantile(0.10)
Q3 = df['cb_person_cred_hist_length'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['cb_person_cred_hist_length'] >= Q1) & (df['cb_person_cred_hist_length'] <= Q3)]

plt.figure(figsize=(8, 6))

# Plot KDE for the filtered data
sns.kdeplot(df['cb_person_cred_hist_length'], color='blue')

# Plot the original KDE for comparison
# Out:
# <Axes: xlabel='cb_person_cred_hist_length', ylabel='Density'>

# %% [markdown]
# ## Categoirical Columns

# %% [markdown]
# #### loan_status

# %% [markdown]
# - Data is imbalanced

# %%
ax = sns.countplot(x='loan_status', data=df, palette='pastel')
ax.set_xlabel('loan_status')
ax.set_ylabel('Count')
ax.set_title('Count of loan_status')

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')

# ax.grid(axis='y')

# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\894827525.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='loan_status', data=df, palette='pastel')

# %% [markdown]
# #### person_home_ownership

# %%
ax = sns.countplot(x='person_home_ownership', data=df, palette='pastel')
ax.set_xlabel('Home Ownership')
ax.set_ylabel('Count')
ax.set_title('Count of Home Ownership')

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')

# ax.grid(axis='y')

# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\1197086635.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='person_home_ownership', data=df, palette='pastel')

# %% [markdown]
# #### loan intent

# %% [markdown]
# - loan_intent has no ditribution

# %%
ax = sns.countplot(x='loan_intent', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('Loan Intent')
ax.set_ylabel('Count')
ax.set_title('Loan Intent Distribution')

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
# ax.grid(axis='y')

# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\2501164896.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='loan_intent', data=df, palette='pastel')

# %% [markdown]
# #### loan_grade

# %% [markdown]
# - Customers of loan grade A and B have are more customers

# %%
ax = sns.countplot(x='loan_grade', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('loan_grade')
ax.set_ylabel('Count')
ax.set_title('loan_grade Distribution')

# Calculate percentages and add annotations
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')
# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\181013696.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='loan_grade', data=df, palette='pastel')

# %% [markdown]
# #### cb_person_default_on_file

# %%
ax = sns.countplot(x='cb_person_default_on_file', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('cb_person_default_on_file')
ax.set_ylabel('Count')
ax.set_title('cb_person_default_on_file Distribution')

# Calculate percentages and add annotations
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')
# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\1512283171.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='cb_person_default_on_file', data=df, palette='pastel')

# %%
bins = [20, 25, 30, 35, 40]
labels = ['20-25', '26-30', '31-35', '36-40']

# Bin the ages
df['Age Group'] = pd.cut(df['person_age'], bins=bins, labels=labels, right=False)

# Display the DataFrame
# print(df)

# %%
bins = [0,15000, 25000, 40000, 55000, 70000, 85000, 100000, 115000, 130000, 145000]
labels = ['0-15000', '15001-25000', '25001-40000', '40001-55000', '55001-70000', '70001-85000', '85001-100000', '100001-115000', '115001-130000', '130001-145000',]

# Bin the incomes
df['Income Group'] = pd.cut(df['person_income'], bins=bins, labels=labels, right=False)

# Display the DataFrame
# print(df)

# %%
bins = [0, 5000, 10000, 15000, 20000, 25000, 30000]
labels = ['0-5000', '5001-10000', '10001-15000', '15001-20000', '20001-25000', '25001-30000']

# Bin the loan amounts
df['Loan amnt Group'] = pd.cut(df['loan_amnt'], bins=bins, labels=labels, right=False)

# Display the DataFrame
# print(df)

# %%
df['loan_status1'] = df['loan_status'].replace({0: 'Yes', 1: 'No'})

# %%
ax = sns.countplot(x='Age Group', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('Age Group')
ax.set_ylabel('Count')
ax.set_title('Age Group Distribution')

# Calculate percentages and add annotations
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')
# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\3167956594.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Age Group', data=df, palette='pastel')

# %%
plt.figure(figsize=(16, 6))

ax = sns.countplot(x='Income Group', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('Income Group')
ax.set_ylabel('Count')
ax.set_title('Income Group Distribution')
# Calculate percentages and add annotations
total = float(len(df))

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')
# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\1817331028.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Income Group', data=df, palette='pastel')

# %%
plt.figure(figsize=(16, 6))

ax = sns.countplot(x='Loan amnt Group', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('Loan amnt Group')
ax.set_ylabel('Count')
ax.set_title('Loan amnt Group Distribution')
# Calculate percentages and add annotations
total = float(len(df))

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')
# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\1196641813.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Loan amnt Group', data=df, palette='pastel')

# %%
plt.figure(figsize=(16, 6))

ax = sns.countplot(x='loan_status1', data=df, palette='pastel')

# Set labels and title
ax.set_xlabel('Loan amnt Group')
ax.set_ylabel('Count')
ax.set_title('Loan amnt Group Distribution')
# Calculate percentages and add annotations
total = float(len(df))

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center')
# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\569165631.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='loan_status1', data=df, palette='pastel')

# %% [markdown]
# # Bivariate

# %% [markdown]
# #### Person age vs laon status

# %% [markdown]
# - Age ranging from 22 to 26 is generally considered to be associated with lower credit risk compared to other age groups.

# %%
grouped_data = pd.crosstab(df['Age Group'], df['loan_status'])

# Plot the grouped bar plot
ax = grouped_data.plot(kind='bar', stacked=False, figsize=(10, 6))

# Set labels and title
plt.title('Age Group vs Loan Status')
plt.xlabel('Loan Grade')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend(title='Loan Status')

# Calculate total counts for each loan grade
total_counts_by_grade = grouped_data.sum(axis=1)

# Calculate percentages and add annotations
for i in range(len(grouped_data.index)):
    for j in range(len(grouped_data.columns)):
        count = grouped_data.iloc[i, j]
        percentage = (count / total_counts_by_grade[i]) * 100
        ax.text(
            i + j * 0.2 - 0.15, count + 0.5,  # Adjust the position of the text
            f'{percentage:.1f}%', 
            ha='center', va='bottom'
        )

# Remove grid lines for better readability
# ax.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\4266350511.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   percentage = (count / total_counts_by_grade[i]) * 100

# %% [markdown]
# #### Income Group vs loan status

# %%
grouped_data = pd.crosstab(df['Income Group'], df['loan_status'])

# Plot the grouped bar plot
ax = grouped_data.plot(kind='bar', stacked=False, figsize=(10, 6))

# Set labels and title
plt.title('Income Group vs Loan Status')
plt.xlabel('Income Group')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend(title='Loan Status')

# Calculate total counts for each loan grade
total_counts_by_grade = grouped_data.sum(axis=1)

# Calculate percentages and add annotations
for i in range(len(grouped_data.index)):
    for j in range(len(grouped_data.columns)):
        count = grouped_data.iloc[i, j]
        percentage = (count / total_counts_by_grade[i]) * 100
        ax.text(
            i + j * 0.2 - 0.15, count + 0.5,  # Adjust the position of the text
            f'{percentage:.1f}%', 
            ha='center', va='bottom'
        )

# Remove grid lines for better readability
# ax.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\3878751993.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   percentage = (count / total_counts_by_grade[i]) * 100

# %% [markdown]
# #### loan grade vs loan status

# %% [markdown]
# - Loan Grade A & B & C can be credit free risk among other loan grade people

# %%
grouped_data = pd.crosstab(df['loan_grade'], df['loan_status'])

# Plot the grouped bar plot
ax = grouped_data.plot(kind='bar', stacked=False, figsize=(10, 6))

# Set labels and title
plt.title('Loan Grade vs Loan Status')
plt.xlabel('Loan Grade')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend(title='Loan Status')

# Calculate total counts for each loan grade
total_counts_by_grade = grouped_data.sum(axis=1)

# Calculate percentages and add annotations
for i in range(len(grouped_data.index)):
    for j in range(len(grouped_data.columns)):
        count = grouped_data.iloc[i, j]
        percentage = (count / total_counts_by_grade[i]) * 100
        ax.text(
            i + j * 0.2 - 0.15, count + 0.5,  # Adjust the position of the text
            f'{percentage:.1f}%', 
            ha='center', va='bottom'
        )

# Remove grid lines for better readability
# ax.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\3751183202.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   percentage = (count / total_counts_by_grade[i]) * 100

# %% [markdown]
# #### loan_intent vs loan_status

# %% [markdown]
# - Loan intent like Education, Venture, Medical, personal can be credit free risk among other loan intent people

# %%
loan_intent_grade_ct = pd.crosstab(df['loan_intent'], df['loan_status'])

# Plot the grouped bar plot
ax = loan_intent_grade_ct.plot(kind='bar', figsize=(10, 6))

# Set labels and title
plt.title('Loan Intent vs Loan Status')
plt.xlabel('Loan Intent')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Calculate total count for each loan intent
total_counts = loan_intent_grade_ct.sum(axis=1)

# Calculate percentages and add annotations
for i in range(len(loan_intent_grade_ct.index)):
    for j in range(len(loan_intent_grade_ct.columns)):
        count = loan_intent_grade_ct.iloc[i, j]
        percentage = (count / total_counts[i]) * 100
        ax.text(
            i + j * 0.2 - 0.15, count + 0.5,  # Adjust the position of the text
            f'{percentage:.1f}%', 
            ha='center', va='bottom'
        )

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\142364662.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   percentage = (count / total_counts[i]) * 100

# %% [markdown]
# #### person_home_ownership vs loan_status

# %% [markdown]
# - person_home_ownership of Mortage, Own, Rent can be credit free risk from others

# %%
grouped_data = pd.crosstab(df['person_home_ownership'], df['loan_status'])

# Plot the grouped bar plot
ax = grouped_data.plot(kind='bar', figsize=(10, 6))

# Set labels and title
plt.title('Person Home Ownership vs Loan Status')
plt.xlabel('Person Home Ownership')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend(title='Loan Status')

# Calculate total count within each home ownership category
total_by_home_ownership = grouped_data.sum(axis=1)

# Calculate percentages and add annotations
for i in range(len(grouped_data.index)):
    for j in range(len(grouped_data.columns)):
        count = grouped_data.iloc[i, j]
        percentage = (count / total_by_home_ownership[i]) * 100
        ax.text(
            i + j * 0.2 - 0.15, count + 0.5,  # Adjust the position of the text
            f'{percentage:.1f}%', 
            ha='center', va='bottom'
        )

# ax.grid(axis='y')
# Show the plot
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\4188846912.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   percentage = (count / total_by_home_ownership[i]) * 100

# %% [markdown]
# #### cb_person_default_on_file vs loan_status

# %% [markdown]
# - loan-intent 'no' has highest count for loan status 0

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='cb_person_default_on_file', hue='loan_status', data=df)

# Set labels and title
plt.xlabel('cb person default on file')
plt.ylabel('Count')
plt.title('cb person default on file vs Loan Status')

# Calculate total counts for each 'cb_person_default_on_file' category
total_counts = df.groupby('cb_person_default_on_file')['loan_status'].count()

# Calculate percentages and add annotations
for p in ax.patches:
    height = p.get_height()
    # Get the 'cb_person_default_on_file' category for the current bar
    cb_person_default_on_file = p.get_x() + p.get_width() / 2.0
    # Adjust the index to ensure correct category mapping
    cb_person_default_on_file = 'Y' if round(cb_person_default_on_file) == 0 else 'N'
    
    # Get the total count for this category
    total = total_counts[cb_person_default_on_file]
    
    # Calculate percentage
    if height != 0:  # Skip annotating bars with zero count
        percentage = (height / total) * 100
        
        # Annotate the bar with the percentage
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{percentage:.1f}%', ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### loan_int_rate vs laon_status

# %% [markdown]
# - loan_int_rate is widely ditributed with for credit free risk

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['loan_status1'], y=df['loan_int_rate'], palette='pastel')
plt.xlabel('Loan Status')
plt.ylabel('Loan Interest Rate')
plt.title('Loan Interest Rate vs Loan Status')
plt.show()
# Out:
# C:\Users\koushik\AppData\Local\Temp\ipykernel_6160\4200028729.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['loan_status1'], y=df['loan_int_rate'], palette='pastel')

# %% [markdown]
# # Multivariate

# %% [markdown]
# #### person_emp_length vs loan_intent vs loan_status

# %%
Q1 = df['person_emp_length'].quantile(0.10)
Q3 = df['person_emp_length'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['person_emp_length'] >= Q1) & (df['person_emp_length'] <= Q3)]

plt.figure(figsize=(16, 6))
sns.boxplot(x='loan_intent', y='person_emp_length',hue='loan_status' ,data=df)
plt.title('Box Plot of Numerical Variable by Categorical Variable')
plt.show()

# %% [markdown]
# #### person_income vs loan_intent vs loan_status

# %%
Q1 = df['person_income'].quantile(0.10)
Q3 = df['person_income'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['person_income'] >= Q1) & (df['person_income'] <= Q3)]


plt.figure(figsize=(16, 6))
sns.boxplot(y='person_income', x='loan_intent',hue='loan_status' ,data=df)
plt.title('Box Plot of Numerical Variable by Categorical Variable')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='loan_grade', y='loan_intent',hue='loan_status' ,data=df)
plt.title('Box Plot of Numerical Variable by ategorical Variable')
plt.show()

# %%
Q1 = df['person_age'].quantile(0.10)
Q3 = df['person_age'].quantile(0.90)

# Filter the data to include only values within the IQR
df = df[(df['person_age'] >= Q1) & (df['person_age'] <= Q3)]


plt.figure(figsize=(16, 6))
sns.boxplot(y='person_age',x= 'loan_intent',hue='loan_status' ,data=df)
plt.title('Box Plot of Numerical Variable by ategorical Variable')
plt.show()

# %%
df['loan_status1'] = df['loan_status'].replace({0: 'Yes', 1: 'No'})

# %%
df.to_csv('credit_data2.csv')
